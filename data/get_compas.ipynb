# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/propublica/compas-analysis/master/compas-scores-two-years.csv")
print(df.shape)
df.head()
# Out:
# (7214, 53)
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race      ...        \
# 0  1947-04-18   69  Greater than 45             Other      ...
# 1  1982-01-22   34          25 - 45  African-American      ...
# 2  1991-05-14   24     Less than 25  African-American      ...
# 3  1993-01-21   23     Less than 25  African-American      ...
# 4  1973-01-22   43          25 - 45             Other      ...
#
#    v_decile_score  v_score_text  v_screening_date  in_custody  out_custody  \
# ...

# %%
df.tail()
# Out:
#          id                 name      first       last compas_screening_date  \
# 7209  10996        steven butler     steven     butler            2013-11-23
# 7210  10997      malcolm simmons    malcolm    simmons            2014-02-01
# 7211  10999      winston gregory    winston    gregory            2014-01-14
# 7212  11000          farrah jean     farrah       jean            2014-03-09
# 7213  11001  florencia sanmartin  florencia  sanmartin            2014-06-30
#
#          sex         dob  age          age_cat              race  \
# 7209    Male  1992-07-17   23     Less than 25  African-American
# 7210    Male  1993-03-25   23     Less than 25  African-American
# 7211    Male  1958-10-01   57  Greater than 45             Other
# 7212  Female  1982-11-17   33          25 - 45  African-American
# 7213  Female  1992-12-18   23     Less than 25          Hispanic
#
#           ...        v_decile_score  v_score_text  v_screening_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7214 entries, 0 to 7213
# Data columns (total 53 columns):
# id                         7214 non-null int64
# name                       7214 non-null object
# first                      7214 non-null object
# last                       7214 non-null object
# compas_screening_date      7214 non-null object
# sex                        7214 non-null object
# dob                        7214 non-null object
# age                        7214 non-null int64
# age_cat                    7214 non-null object
# race                       7214 non-null object
# juv_fel_count              7214 non-null int64
# decile_score               7214 non-null int64
# juv_misd_count             7214 non-null int64
# juv_other_count            7214 non-null int64
# priors_count               7214 non-null int64
# days_b_screening_arrest    6907 non-null float64
# c_jail_in                  6907 non-null object
# ...

# %%
columns = ["sex", "age", "juv_fel_count", "juv_misd_count", "juv_other_count", "priors_count", "c_charge_degree", "race", "two_year_recid"]
df_com = df[columns]
df_com.head()
# Out:
#     sex  age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 0  Male   69              0               0                0             0
# 1  Male   34              0               0                0             0
# 2  Male   24              0               0                1             4
# 3  Male   23              0               1                0             1
# 4  Male   43              0               0                0             2
#
#   c_charge_degree              race  two_year_recid
# 0               F             Other               0
# 1               F  African-American               1
# 2               F  African-American               1
# 3               F  African-American               0
# 4               F             Other               0

# %%
df_com.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7214 entries, 0 to 7213
# Data columns (total 9 columns):
# sex                7214 non-null object
# age                7214 non-null int64
# juv_fel_count      7214 non-null int64
# juv_misd_count     7214 non-null int64
# juv_other_count    7214 non-null int64
# priors_count       7214 non-null int64
# c_charge_degree    7214 non-null object
# race               7214 non-null object
# two_year_recid     7214 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 507.3+ KB

# %%
ages = []

for _, val in df_com["age"].iteritems():
    #print(row, val)
    if val <= 20:
        ages.append("18-20")
    elif val <= 22:
        #df_com["age"][row] = "21-22"
        ages.append("21-22")
    elif val <= 25:
        #df_com["age"][row] = "23-25"
        ages.append("23-25")
    elif val <= 45:
        #df_com["age"][row] = "26-45"
        ages.append("26-45")
    else:
        #df_com["age"][row] = ">45"
        ages.append(">45")
        
df_com.age = ages
df_com.head()
# Out:
# /Users/mata_kota/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#     sex    age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 0  Male    >45              0               0                0             0
# 1  Male  26-45              0               0                0             0
# 2  Male  23-25              0               0                1             4
# 3  Male  23-25              0               1                0             1
# 4  Male  26-45              0               0                0             2
#
#   c_charge_degree              race  two_year_recid
# 0               F             Other               0
# ...

# %%
age_list = sorted(df_com.age.unique())
for i in age_list:
    print(i, len(df_com[df_com.age==i]))
# Out:
# 18-20 220
# 21-22 623
# 23-25 1018
# 26-45 3890
# >45 1463

# %%
priors = []
p = df_com["priors_count"].values
#print(p)

for val in p:
    #print(row, val)
    if val == 0:
        priors.append("=0")
    elif val <= 1:
        #df_com["age"][row] = "21-22"
        priors.append("=1")
    elif val <= 3:
        #df_com["age"][row] = "23-25"
        priors.append("2-3")
    else:
        #df_com["age"][row] = ">45"
        priors.append(">3")
        
df_com["priors"] = priors
df_com.head()
# Out:
# /Users/mata_kota/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     sex    age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 0  Male    >45              0               0                0             0
# 1  Male  26-45              0               0                0             0
# 2  Male  23-25              0               0                1             4
# 3  Male  23-25              0               1                0             1
# 4  Male  26-45              0               0                0             2
#
#   c_charge_degree              race  two_year_recid priors
# 0               F             Other               0     =0
# ...

# %%
pri_list = sorted(df_com.priors.unique())
for i in pri_list:
    print(i, len(df_com[df_com.priors==i]))
# Out:
# 2-3 1408
# =0 2150
# =1 1397
# >3 2259

# %%
j_fel = []
p = df_com["juv_fel_count"].values
#print(p)

for val in p:
    #print(row, val)
    if val == 0:
        j_fel.append("=0")
    else:
        #df_com["age"][row] = ">45"
        j_fel.append(">0")
        
df_com["juvenile-felonies"] = j_fel
df_com.head()
# Out:
# /Users/mata_kota/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#     sex    age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 0  Male    >45              0               0                0             0
# 1  Male  26-45              0               0                0             0
# 2  Male  23-25              0               0                1             4
# 3  Male  23-25              0               1                0             1
# 4  Male  26-45              0               0                0             2
#
#   c_charge_degree              race  two_year_recid priors juvenile-felonies
# ...

# %%
print("=0", len(df_com[df_com["juvenile-felonies"]=="=0"]))
print(">0", len(df_com[df_com["juvenile-felonies"]==">0"]))
# Out:
# =0 6932
# >0 282

# %%
j_mis = []
p = df_com["juv_misd_count"].values
#print(p)

for val in p:
    #print(row, val)
    if val == 0:
        j_mis.append("=0")
    else:
        #df_com["age"][row] = ">45"
        j_mis.append(">0")
        
df_com["juvenile-misdemeanors"] = j_mis
df_com.head()
# Out:
# /Users/mata_kota/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#     sex    age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 0  Male    >45              0               0                0             0
# 1  Male  26-45              0               0                0             0
# 2  Male  23-25              0               0                1             4
# 3  Male  23-25              0               1                0             1
# 4  Male  26-45              0               0                0             2
#
#   c_charge_degree              race  two_year_recid priors juvenile-felonies  \
# ...

# %%
print("=0", len(df_com[df_com["juvenile-misdemeanors"]=="=0"]))
print(">0", len(df_com[df_com["juvenile-misdemeanors"]==">0"]))
# Out:
# =0 6799
# >0 415

# %%
j_cri = []
fel = df_com["juv_fel_count"].values
misd = df_com["juv_misd_count"].values
other = df_com["juv_other_count"].values
#print(p)

for i in range(len(fel)):
    #print(row, val)
    val = fel[i] + misd[i] + other[i]
    
    if val == 0:
        j_cri.append("=0")
    else:
        #df_com["age"][row] = ">45"
        j_cri.append(">0")
        
df_com["juvenile-crimes"] = j_cri
df_com.head()
# Out:
# /Users/mata_kota/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     sex    age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 0  Male    >45              0               0                0             0
# 1  Male  26-45              0               0                0             0
# 2  Male  23-25              0               0                1             4
# 3  Male  23-25              0               1                0             1
# 4  Male  26-45              0               0                0             2
#
#   c_charge_degree              race  two_year_recid priors juvenile-felonies  \
# ...

# %%
print("=0", len(df_com[df_com["juvenile-crimes"]=="=0"]))
print(">0", len(df_com[df_com["juvenile-crimes"]==">0"]))
# Out:
# =0 6241
# >0 973

# %%
cl = []
c = df_com["c_charge_degree"].values
#print(p)

for val in c:
    #print(row, val)
    if val == "F":
        cl.append("Felony")
    else:
        #df_com["age"][row] = ">45"
        cl.append("Misdemeanor")
        
df_com["current-charge-degree"] = cl
df_com.head()
# Out:
# /Users/mata_kota/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#     sex    age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 0  Male    >45              0               0                0             0
# 1  Male  26-45              0               0                0             0
# 2  Male  23-25              0               0                1             4
# 3  Male  23-25              0               1                0             1
# 4  Male  26-45              0               0                0             2
#
#   c_charge_degree              race  two_year_recid priors juvenile-felonies  \
# ...

# %%
column = ['sex', 'age', 'juvenile-felonies', 'juvenile-misdemeanors',
       'juvenile-crimes', 'priors', 'current-charge-degree', 'race', 
       'two_year_recid']
df_pre = df_com[column]
df_pre = df_pre.rename(columns={'two_year_recid': 'recidivate-within-two-years'})
df_pre.head()
# Out:
#     sex    age juvenile-felonies juvenile-misdemeanors juvenile-crimes priors  \
# 0  Male    >45                =0                    =0              =0     =0
# 1  Male  26-45                =0                    =0              =0     =0
# 2  Male  23-25                =0                    =0              >0     >3
# 3  Male  23-25                =0                    >0              >0     =1
# 4  Male  26-45                =0                    =0              =0    2-3
#
#   current-charge-degree              race  recidivate-within-two-years
# 0                Felony             Other                            0
# 1                Felony  African-American                            1
# 2                Felony  African-American                            1
# 3                Felony  African-American                            0
# 4                Felony             Other                            0

# %%
del_index = [7210, 7211, 7212, 7213]
print(del_index)
df_del = df_pre.drop(del_index)
df_del.tail()
# Out:
# [7210, 7211, 7212, 7213]
#        sex    age juvenile-felonies juvenile-misdemeanors juvenile-crimes  \
# 7205  Male  23-25                =0                    >0              >0
# 7206  Male  21-22                =0                    =0              =0
# 7207  Male  26-45                =0                    =0              =0
# 7208  Male  18-20                =0                    =0              =0
# 7209  Male  23-25                =0                    =0              =0
#
#      priors current-charge-degree              race  \
# 7205     >3           Misdemeanor         Caucasian
# 7206     =0           Misdemeanor         Caucasian
# 7207     =0           Misdemeanor  African-American
# 7208     =0                Felony  African-American
# 7209     =0                Felony  African-American
#
#       recidivate-within-two-years
# 7205                            1
# 7206                            1
# 7207                            1
# 7208                            0
# ...

# %%
seed = sum([3, 15, 13, 16, 1, 19]) # c:3, o:15, m:13, p:16, a:1, s:19
np.random.seed(seed)
split_ind = np.split(np.random.permutation(len(df_del)), 10)
print(split_ind)
# Out:
# [array([5460, 4996, 5661,  885, 1223, 5480, 6101,  825, 2502, 6308, 5200,
#        2101, 3140, 5378, 3336, 4486, 5418, 2909, 3251,  229, 2930, 1938,
#        1133, 2207, 1413, 1008, 5963,  704, 6970, 1839, 4800, 2658, 3384,
#        3571, 1063, 1669, 5759, 5944, 2965, 6953,  291, 1000, 3978, 4367,
#        2212, 5911, 5831,  345, 5053,  789, 4797, 3587, 5641, 2394, 6035,
#         225, 5761,   87, 1703, 3092, 4674, 3499, 6110, 1674, 3312, 6642,
#        3706, 5914, 5043, 4828, 2168,  412, 5979, 3267,  929,  529, 2104,
#        3475, 1724, 2732, 6025, 1746, 5548, 7093, 4264, 5220, 1134, 4006,
#        2220,  913, 3249, 1097, 3399, 3101, 2563, 5412, 4546, 5131, 4976,
#         538,  237, 4025, 2730, 6097, 6218, 1696,  480, 6784, 1663, 4154,
#        3520, 4662,  174, 5155, 3157, 1759, 4456, 4335,  129, 6879, 1269,
#        5854,  610, 4082, 4928, 3659, 4776,  227, 4757, 4693, 5581, 5400,
#        5882, 4611, 6217, 2765, 2120, 7084, 1794, 2688, 5552,   47, 5620,
# ...

# %%
df_test = df_del.iloc[split_ind[0]].reset_index()
df_test = df_test.drop("index", axis=1)

df_test
# Out:
#         sex    age juvenile-felonies juvenile-misdemeanors juvenile-crimes  \
# 0      Male  26-45                =0                    =0              =0
# 1      Male  26-45                =0                    =0              =0
# 2      Male  26-45                =0                    =0              =0
# 3      Male  23-25                =0                    =0              =0
# 4      Male  26-45                =0                    =0              =0
# 5    Female  26-45                >0                    =0              >0
# 6      Male  26-45                =0                    =0              =0
# 7      Male  23-25                =0                    =0              =0
# 8      Male  26-45                =0                    =0              =0
# 9    Female  26-45                =0                    =0              =0
# 10     Male  26-45                =0                    =0              =0
# ...

# %%
df_train = df_del.iloc[split_ind[1]]
for i in np.arange(2, 10):
    df_add = df_del.iloc[split_ind[i]]
    df_train = pd.concat([df_train, df_add])

df_train = df_train.reset_index().drop("index", axis=1)
df_train
# Out:
#          sex    age juvenile-felonies juvenile-misdemeanors juvenile-crimes  \
# 0     Female  18-20                =0                    =0              =0
# 1       Male  26-45                =0                    =0              =0
# 2       Male  26-45                =0                    =0              =0
# 3       Male  23-25                =0                    =0              =0
# 4       Male  26-45                =0                    =0              =0
# 5       Male  26-45                =0                    =0              =0
# 6     Female    >45                =0                    =0              =0
# 7       Male    >45                =0                    =0              =0
# 8     Female  26-45                =0                    =0              =0
# 9       Male  21-22                =0                    =0              =0
# 10      Male  26-45                =0                    =0              =0
# ...

# %%
df_train.to_csv("compas_train_race.csv")
df_test.to_csv("compas_test_race.csv")
